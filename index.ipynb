# %% [markdown]
# # Project - EDA with Pandas Using the Boston Housing Data

# %% [markdown]
# ## Introduction
#
# In this section you've learned a lot about importing, cleaning up, analysing (using descriptive statistics) and visualizing data. In this more free form project you'll get a chance to practice all of these skills with the Boston Housing data set,  which contains housing values in suburbs of Boston. The Boston Housing Data is commonly used by aspiring data scientists.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section

# %% [markdown]
# # Goals
#
# Use your data munging and visualization skills to conduct an exploratory analysis of the dataset below. At minimum, this should include:
#
# * Loading the data (which is stored in the file train.csv)
# * Use built-in python functions to explore measures of centrality and dispersion for at least 3 variables
# * Create *meaningful* subsets of the data using selection operations using `.loc`, `.iloc` or related operations. Explain why you used the chosen subsets and do this for 3 possible 2-way splits. State how you think the 2 measures of centrality and/or dispersion might be different for each subset of the data. Examples of potential splits:
#     - Create a 2 new dataframes based on your existing data, where one contains all the properties next to the Charles river, and the other one contains properties that aren't.
#     - Create 2 new datagrames based on a certain split for crime rate.
# * Next, use histograms and scatterplots to see whether you observe differences for the subsets of the data. Make sure to use subplots so it is easy to compare the relationships.

# %% [markdown]
# # Variable Descriptions
#
# This data frame contains the following columns:
#
# #### crim
# per capita crime rate by town.
#
# #### zn
# proportion of residential land zoned for lots over 25,000 sq.ft.
#
# #### indus
# proportion of non-retail business acres per town.
#
# #### chas
# Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# #### nox
# nitrogen oxides concentration (parts per 10 million).
#
# #### rm
# average number of rooms per dwelling.
#
# #### age
# proportion of owner-occupied units built prior to 1940.
#
# #### dis
# weighted mean of distances to five Boston employment centres.
#
# #### rad
# index of accessibility to radial highways.
#
# #### tax
# full-value property-tax rate per $10,000.
#
# #### ptratio
# pupil-teacher ratio by town.
#
# #### black
# 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# #### lstat
# lower status of the population (percent).
#
# #### medv
# median value of owner-occupied homes in $10000s.
#
#
#
# Source
# Harrison, D. and Rubinfeld, D.L. (1978) Hedonic prices and the demand for clean air. J. Environ. Economics and Management 5, 81–102.
#
# Belsley D.A., Kuh, E. and Welsch, R.E. (1980) Regression Diagnostics. Identifying Influential Data and Sources of Collinearity. New York: Wiley.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
# ID         333 non-null int64
# crim       333 non-null float64
# zn         333 non-null float64
# indus      333 non-null float64
# chas       333 non-null int64
# nox        333 non-null float64
# rm         333 non-null float64
# age        333 non-null float64
# dis        333 non-null float64
# rad        333 non-null int64
# tax        333 non-null int64
# ptratio    333 non-null float64
# black      333 non-null float64
# lstat      333 non-null float64
# medv       333 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
df_river = df[df['chas']==1]
df_river.head()
# Out:
#       ID     crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 97   143  3.32105  0.0  19.58     1  0.871  5.403  100.0  1.3216    5  403
# 104  155  1.41385  0.0  19.58     1  0.871  6.129   96.0  1.7494    5  403
# 108  161  1.27346  0.0  19.58     1  0.605  6.250   92.6  1.7984    5  403
# 110  164  1.51902  0.0  19.58     1  0.605  8.375   93.9  2.1620    5  403
# 145  209  0.13587  0.0  10.59     1  0.489  6.064   59.1  4.2392    4  277
#
#      ptratio   black  lstat  medv
# 97      14.7  396.90  26.82  13.4
# 104     14.7  321.02  15.12  17.0
# 108     14.7  338.92   5.50  27.0
# 110     14.7  388.45   3.32  50.0
# 145     18.6  381.32  14.66  24.4

# %%
df_river.describe()
# Out:
#                ID       crim         zn      indus  chas        nox  \
# count   20.000000  20.000000  20.000000  20.000000  20.0  20.000000
# mean   255.600000   2.163972   8.500000  12.330000   1.0   0.593595
# std     75.913663   2.885734  21.830688   6.505255   0.0   0.146237
# min    143.000000   0.015010   0.000000   1.210000   1.0   0.401000
# 25%    211.250000   0.200377   0.000000   6.200000   1.0   0.489000
# 50%    236.000000   0.572070   0.000000  12.240000   1.0   0.528500
# 75%    302.250000   3.453213   0.000000  18.100000   1.0   0.693500
# max    373.000000   8.982960  90.000000  19.580000   1.0   0.871000
#
#               rm         age        dis        rad         tax   ptratio  \
# count  20.000000   20.000000  20.000000  20.000000   20.000000  20.00000
# mean    6.577750   75.815000   3.069540   9.900000  394.550000  17.38500
# std     0.814341   22.808638   1.343724   8.534142  171.795005   2.22906
# ...

# %%
df_land = df[df['chas']==0]
df_land.describe()
# Out:
#                ID        crim          zn       indus   chas         nox  \
# count  313.000000  313.000000  313.000000  313.000000  313.0  313.000000
# mean   250.654952    3.436787   10.829073   11.227252    0.0    0.554815
# std    151.365227    7.544289   22.754198    7.032974    0.0    0.112555
# min      1.000000    0.006320    0.000000    0.740000    0.0    0.385000
# 25%    118.000000    0.078750    0.000000    4.950000    0.0    0.453000
# 50%    245.000000    0.245220    0.000000    9.690000    0.0    0.538000
# 75%    387.000000    3.678220   12.500000   18.100000    0.0    0.624000
# max    506.000000   73.534100  100.000000   27.740000    0.0    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  313.000000  313.000000  313.000000  313.000000  313.000000  313.000000
# mean     6.245674   67.741534    3.750853    9.616613  410.220447   18.515974
# ...

# %%
new_figure = plt.figure(figsize=(10,4))


ax = new_figure.add_subplot(121)
ax2 = new_figure.add_subplot(122)

ax.hist(df_river['medv'], label = 'Boston Suburbs')
ax2.hist(df_land['medv'], label = 'Boston Suburbs')

ax.set_title('On Charels River')
ax2.set_title('Not on River')

ax.set_xlabel("median home value in $10000")
ax2.set_xlabel('median home value in $10000')
ax.legend()
ax2.legend()

plt.show()

# %%
new_figure = plt.figure(figsize=(14,6))

# Add a subplot to the figure - a new axes
ax = new_figure.add_subplot(121)

# Add a second subplot to the figure - a new axes
ax2 = new_figure.add_subplot(122)

# Generate a line plot on first axes
ax.scatter(df_river['dis'], df_river['crim'])

# Draw a scatter plot on 2nd axes
ax2.scatter(df_land['dis'], df_land['crim'], color='red')


ax.set_xlabel('Distance to Employment Center')
ax.set_ylabel('Per Capita Crime')
ax.set_title('On River')

ax2.set_xlabel('Distance to Employment Center')
ax2.set_ylabel('Per Capita Crime')
ax2.set_title('Not On River')

plt.show()

# %%
df_LotsOfTeachers = df[df['ptratio']<=19]
df_FewTeachers = df[df['ptratio']>19]

# %%
df_LotsOfTeachers.describe()
# Out:
#                ID        crim         zn       indus        chas         nox  \
# count  168.000000  168.000000  168.00000  168.000000  168.000000  168.000000
# mean   183.505952    0.414618   18.03869    7.484167    0.089286    0.509375
# std     95.336341    0.697973   27.70298    5.578822    0.286008    0.111094
# min      1.000000    0.006320    0.00000    0.740000    0.000000    0.385000
# 25%     93.250000    0.051557    0.00000    3.410000    0.000000    0.437000
# 50%    185.500000    0.101185    0.00000    6.090000    0.000000    0.488000
# 75%    265.250000    0.403442   25.75000   10.010000    0.000000    0.544000
# max    353.000000    3.321050  100.00000   19.580000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  168.000000  168.000000  168.000000  168.000000  168.000000  168.000000
# mean     6.514554   57.926190    4.360267    4.488095  307.059524   16.718452
# ...

# %%
df_FewTeachers.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean   319.624242    6.359623    3.206061   15.172061    0.030303    0.605782
# std    159.994449    9.539114   12.151732    6.119595    0.171942    0.097295
# min     14.000000    0.013600    0.000000    1.250000    0.000000    0.410000
# 25%    137.000000    0.195390    0.000000    8.560000    0.000000    0.538000
# 50%    378.000000    3.693110    0.000000   18.100000    0.000000    0.609000
# 75%    449.000000    9.187020    0.000000   18.100000    0.000000    0.693000
# max    506.000000   73.534100   80.000000   27.740000    1.000000    0.770000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean     6.012158   78.713939    3.047776   14.872727  513.357576   20.209091
# ...

# %%
new_figure = plt.figure(figsize=(14,6))


ax = new_figure.add_subplot(121)
ax2 = new_figure.add_subplot(122)

ax.hist(df_LotsOfTeachers['crim'], label = 'Boston Suburbs',bins = 20)
ax2.hist(df_FewTeachers['crim'],label = 'Boston Suburbs', bins = 20)

ax.set_title('Lots of Teachers')
ax2.set_title('Fewer Teachers')

ax.set_xlabel('Crimes Per Capita')
ax2.set_xlabel('Crimes Per Capita')
ax.legend()
ax2.legend()
plt.show()

# %%
new_figure = plt.figure(figsize=(14,6))

# Add a subplot to the figure - a new axes
ax = new_figure.add_subplot(121)

# Add a second subplot to the figure - a new axes
ax2 = new_figure.add_subplot(122)

# Generate a line plot on first axes
ax.scatter(df_LotsOfTeachers['rm'], df_LotsOfTeachers['lstat'])

# Draw a scatter plot on 2nd axes
ax2.scatter(df_FewTeachers['rm'], df_FewTeachers['lstat'], color='red')


ax.set_xlabel('Number of Rooms')
ax.set_ylabel('Percent lower Status')
ax.set_title('Lots of Teachers')

ax2.set_xlabel('Number of Rooms')
ax2.set_ylabel('Percent Lower Status')
ax2.set_title('Fewer Teachers')

plt.show()

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed your first "freeform" exploratory data analysis of a popular data set!

# %%
df_lowTax = df[df['tax']<=330]
df_lowTax.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  169.000000  169.000000  169.000000  169.000000  169.000000  169.000000
# mean   187.449704    0.254323   15.396450    6.812781    0.065089    0.488402
# std    118.521342    0.348411   25.061108    4.728692    0.247415    0.059620
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%     71.000000    0.053020    0.000000    3.970000    0.000000    0.439000
# 50%    209.000000    0.115040    0.000000    5.960000    0.000000    0.489000
# 75%    282.000000    0.331470   22.000000    8.140000    0.000000    0.524000
# max    506.000000    2.635480  100.000000   25.650000    1.000000    0.647000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  169.000000  169.000000  169.000000  169.000000  169.000000  169.000000
# mean     6.483426   55.488757    4.659944    4.402367  271.502959   17.860947
# ...

# %%
df_highTax = df[df['tax']>330]
df_highTax.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  164.000000  164.000000  164.000000  164.000000  164.000000  164.000000
# mean   316.390244    6.561055    5.838415   15.910793    0.054878    0.627982
# std    146.839903    9.469245   18.794737    5.868363    0.228440    0.115342
# min     55.000000    0.013600    0.000000    1.250000    0.000000    0.398000
# 25%    156.500000    0.210572    0.000000   16.782500    0.000000    0.547000
# 50%    373.500000    3.695030    0.000000   18.100000    0.000000    0.624000
# 75%    444.250000    9.198340    0.000000   18.100000    0.000000    0.713000
# max    500.000000   73.534100   95.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  164.000000  164.000000  164.000000  164.000000  164.000000  164.000000
# mean     6.041171   81.352439    2.730959   15.024390  551.256098   19.053049
# ...

# %%
new_figure = plt.figure(figsize=(14,6))


ax = new_figure.add_subplot(121)
ax2 = new_figure.add_subplot(122)

ax.hist(df_highTax['dis'], label = 'Boston Suburbs',bins = 15)
ax2.hist(df_lowTax['dis'], label = 'Boston Suburbs',bins = 15)

ax.set_title('High Tax Areas')
ax2.set_title('Low Tax Areas')

ax.set_xlabel('Distance to Employment Centers')
ax2.set_xlabel('Distance to Employment Centers')
ax.legend()
ax2.legend()
plt.show()

# %%
new_figure = plt.figure(figsize=(14,6))

# Add a subplot to the figure - a new axes
ax = new_figure.add_subplot(121)

# Add a second subplot to the figure - a new axes
ax2 = new_figure.add_subplot(122)

# Generate a line plot on first axes
ax.scatter(df_highTax['indus'], df_highTax['nox'])

# Draw a scatter plot on 2nd axes
ax2.scatter(df_lowTax['indus'], df_lowTax['nox'], color='red')


ax.set_xlabel('proportion nonretail business acres')
ax.set_ylabel('nitrogen oxides concentration (parts per 10 million)')
ax.set_title('High Tax Areas')

ax2.set_xlabel('proportion non-retail business acres')
ax2.set_ylabel('nitrogen oxides concentration (parts per 10 million)')
ax2.set_title('Lower Tax Areas')

plt.show()
